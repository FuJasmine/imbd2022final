# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, RobustScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, Flatten
from keras.layers import Conv1D, Conv2D, MaxPooling2D
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras import backend as K
from keras.layers import Reshape

# %%
# Loading the dataset
path1 = 'train1_data/'
path2 = 'train2_data/'

sg_B1 = np.load(path1 + 'sg_B.npy')
sg_C1 = np.load(path1 + 'sg_C.npy')
sg_D1 = np.load(path1 + 'sg_D.npy')
sg_E1 = np.load(path1 + 'sg_E.npy')
sg_F1 = np.load(path1 + 'sg_F.npy')
sg_G1 = np.load(path1 + 'sg_G.npy')
sg_H1 = np.load(path1 + 'sg_H.npy')
sg_I1 = np.load(path1 + 'sg_I.npy')
BDF_distance1 = np.load(path1 + 'BDF_distance.npy')


spike_A1 = np.load(path1 + 'spike_A.npy')
spike_B1 = np.load(path1 + 'spike_B.npy')
spike_C1 = np.load(path1 + 'spike_C.npy')
spike_D1 = np.load(path1 + 'spike_D.npy')
spike_abs_B1 = np.load(path1 + 'spike_abs_B.npy')
spike_abs_C1 = np.load(path1 + 'spike_abs_C.npy')
spike_abs_D1 = np.load(path1 + 'spike_abs_D.npy')

spike_B_lower_noise1 = np.load(path1 + 'spike_B_lower_noise.npy')
spike_C_lower_noise1 = np.load(path1 + 'spike_C_lower_noise.npy')
spike_abs_B_lower_noise1 = np.load(path1 + 'spike_abs_B_lower_noise.npy')
spike_abs_C_lower_noise1 = np.load(path1 + 'spike_abs_C_lower_noise.npy')

BCD_distance1 = np.load(path1 + 'BCD_distance.npy')
BCD_abs_distance1 = np.load(path1 + 'BCD_abs_distance.npy')

sg_B2 = np.load(path2 + 'sg_B.npy')
sg_C2 = np.load(path2 + 'sg_C.npy')
sg_D2 = np.load(path2 + 'sg_D.npy')
sg_E2 = np.load(path2 + 'sg_E.npy')
sg_F2 = np.load(path2 + 'sg_F.npy')
sg_G2 = np.load(path2 + 'sg_G.npy')
sg_H2 = np.load(path2 + 'sg_H.npy')
sg_I2 = np.load(path2 + 'sg_I.npy')
BDF_distance2 = np.load(path2 + 'BDF_distance.npy')


spike_A2 = np.load(path2 + 'spike_A.npy')
spike_B2 = np.load(path2 + 'spike_B.npy')
spike_C2 = np.load(path2 + 'spike_C.npy')
spike_D2 = np.load(path2 + 'spike_D.npy')
spike_abs_B2 = np.load(path2 + 'spike_abs_B.npy')
spike_abs_C2 = np.load(path2 + 'spike_abs_C.npy')
spike_abs_D2 = np.load(path2 + 'spike_abs_D.npy')

spike_B_lower_noise2 = np.load(path2 + 'spike_B_lower_noise.npy')
spike_C_lower_noise2 = np.load(path2 + 'spike_C_lower_noise.npy')
spike_abs_B_lower_noise2 = np.load(path2 + 'spike_abs_B_lower_noise.npy')
spike_abs_C_lower_noise2 = np.load(path2 + 'spike_abs_C_lower_noise.npy')

BCD_distance2 = np.load(path2 + 'BCD_distance.npy')
BCD_abs_distance2 = np.load(path2 + 'BCD_abs_distance.npy')

# Concatenate the data
sg_B = np.concatenate((sg_B1, sg_B2), axis=0)
sg_C = np.concatenate((sg_C1, sg_C2), axis=0)
sg_D = np.concatenate((sg_D1, sg_D2), axis=0)
sg_E = np.concatenate((sg_E1, sg_E2), axis=0)
sg_F = np.concatenate((sg_F1, sg_F2), axis=0)
sg_G = np.concatenate((sg_G1, sg_G2), axis=0)
sg_H = np.concatenate((sg_H1, sg_H2), axis=0)
sg_I = np.concatenate((sg_I1, sg_I2), axis=0)
BDF_distance = np.concatenate((BDF_distance1, BDF_distance2), axis=0)


spike_A = np.concatenate((spike_A1, spike_A2), axis=0)
spike_B = np.concatenate((spike_B1, spike_B2), axis=0)
spike_C = np.concatenate((spike_C1, spike_C2), axis=0)
spike_D = np.concatenate((spike_D1, spike_D2), axis=0)
spike_abs_B = np.concatenate((spike_abs_B1, spike_abs_B2), axis=0)
spike_abs_C = np.concatenate((spike_abs_C1, spike_abs_C2), axis=0)
spike_abs_D = np.concatenate((spike_abs_D1, spike_abs_D2), axis=0)

spike_B_lower_noise = np.concatenate((spike_B_lower_noise1, spike_B_lower_noise2), axis=0)
spike_C_lower_noise = np.concatenate((spike_C_lower_noise1, spike_C_lower_noise2), axis=0)
spike_abs_B_lower_noise = np.concatenate((spike_abs_B_lower_noise1, spike_abs_B_lower_noise2), axis=0)
spike_abs_C_lower_noise = np.concatenate((spike_abs_C_lower_noise1, spike_abs_C_lower_noise2), axis=0)

BCD_distance = np.concatenate((BCD_distance1, BCD_distance2), axis=0)
BCD_abs_distance = np.concatenate((BCD_abs_distance1, BCD_abs_distance2), axis=0)

output1 = pd.read_csv('train1/00_Wear_data.csv').loc[:, 'MaxWear']
output2 = pd.read_csv('train2/00_Wear_data.csv').loc[:, 'MaxWear']
Output = pd.concat([output1, output2], axis=0).values

# %%
spike_B_sum = spike_B.sum(axis=1)
spike_C_sum = spike_C.sum(axis=1)
spike_D_sum = spike_D.sum(axis=1)

spike_B_lower_noise_sum = spike_B_lower_noise.sum(axis=1)
spike_C_lower_noise_sum = spike_C_lower_noise.sum(axis=1)

spike_B_sg_B_sum = np.array([spike_B[i]-sg_B[i] for i in range(len(spike_B))]).sum(axis=1)
spike_C_sg_D_sum = np.array([spike_C[i]-sg_D[i]
                       for i in range(len(spike_C))]).sum(axis=1)
spike_D_sg_F_sum = np.array([spike_D[i]-sg_F[i]
                       for i in range(len(spike_D))]).sum(axis=1)

# %%
train1_len = 46

df2 = pd.DataFrame()
integrated_spike_B1 = [sum(abs(spike_B_sum[:i]))
                       for i in range(1, train1_len+1)]
integrated_spike_B2 = [sum(abs(spike_B_sum[train1_len+1:i]))
                       for i in range(train1_len+1, len(spike_B_sum)+1)]
integrated_spike_B = integrated_spike_B1 + integrated_spike_B2
df2['integrated_spike_B'] = pd.Series(integrated_spike_B)


integrated_spike_C1 = [sum(abs(spike_C_sum[:i]))
                       for i in range(1, train1_len+1)]
integrated_spike_C2 = [sum(abs(spike_C_sum[train1_len+1:i]))
                       for i in range(train1_len+1, len(spike_C_sum)+1)]
integrated_spike_C = integrated_spike_C1 + integrated_spike_C2
df2['integrated_spike_C'] = pd.Series(integrated_spike_C)

integrated_spike_D1 = [sum(abs(spike_D_sum[:i]))
                       for i in range(1, train1_len+1)]
integrated_spike_D2 = [sum(abs(spike_D_sum[train1_len+1:i]))
                       for i in range(train1_len+1, len(spike_D_sum)+1)]
integrated_spike_D = integrated_spike_D1 + integrated_spike_D2
df2['integrated_spike_D'] = pd.Series(integrated_spike_D)

integrated_spike_B_lower_noise1 = [sum(abs(
    spike_B_lower_noise_sum[:i]))for i in range(1, train1_len+1)]
integrated_spike_B_lower_noise2 = [sum(abs(
    spike_B_lower_noise_sum[train1_len+1:i]))for i in range(train1_len+1, len(spike_B_lower_noise_sum)+1)]
integrated_spike_B_lower_noise = integrated_spike_B_lower_noise1 + \
    integrated_spike_B_lower_noise2
df2['integrated_spike_B_lower_noise'] = pd.Series(
    integrated_spike_B_lower_noise)

integrated_spike_C_lower_noise1 = [sum(abs(
    spike_C_lower_noise_sum[:i]))for i in range(1, train1_len+1)]
integrated_spike_C_lower_noise2 = [sum(abs(
    spike_C_lower_noise_sum[i-1:i]))for i in range(train1_len+1, len(spike_C_lower_noise_sum)+1)]
integrated_spike_C_lower_noise = integrated_spike_C_lower_noise1 + \
    integrated_spike_C_lower_noise2
df2['integrated_spike_C_lower_noise'] = pd.Series(
    integrated_spike_C_lower_noise)

integrated_spike_B_sg_B1 = [sum(abs(spike_B_sg_B_sum[:i]))
                            for i in range(1, train1_len+1)]
integrated_spike_B_sg_B2 = [sum(abs(spike_B_sg_B_sum[train1_len+1:i]))
                            for i in range(train1_len+1, len(spike_B_sg_B_sum)+1)]
integrated_spike_B_sg_B = integrated_spike_B_sg_B1 + integrated_spike_B_sg_B2
df2['integrated_spike_B_sg_B'] = pd.Series(integrated_spike_B_sg_B)

integrated_spike_C_sg_D1 = [sum(abs(spike_C_sg_D_sum[:i]))
                            for i in range(1, train1_len+1)]
integrated_spike_C_sg_D2 = [sum(abs(spike_C_sg_D_sum[train1_len+1:i]))
                            for i in range(train1_len+1, len(spike_C_sg_D_sum)+1)]
integrated_spike_C_sg_D = integrated_spike_C_sg_D1 + integrated_spike_C_sg_D2
df2['integrated_spike_C_sg_D'] = pd.Series(integrated_spike_C_sg_D)

integrated_spike_D_sg_F1 = [sum(abs(spike_D_sg_F_sum[:i]))
                            for i in range(1, train1_len+1)]
integrated_spike_D_sg_F2 = [sum(abs(spike_D_sg_F_sum[train1_len+1:i]))
                            for i in range(train1_len+1, len(spike_D_sg_F_sum)+1)]
integrated_spike_D_sg_F = integrated_spike_D_sg_F1 + integrated_spike_D_sg_F2
df2['integrated_spike_D_sg_F'] = pd.Series(integrated_spike_D_sg_F)


df2['Output'] = pd.Series(Output)

columns = df2.columns
transformer = StandardScaler()
corr = pd.DataFrame(transformer.fit_transform(df2), columns=columns).corr()
print(corr.iloc[-1, :])
# Out:
# integrated_spike_B                0.927961
# integrated_spike_C                0.934113
# integrated_spike_D                0.938540
# integrated_spike_B_lower_noise    0.920061
# integrated_spike_C_lower_noise    0.803822
# integrated_spike_B_sg_B           0.933373
# integrated_spike_C_sg_D           0.940401
# integrated_spike_D_sg_F           0.938536
# Output                            1.000000
# Name: Output, dtype: float64

# %%
print(df2.columns)
Model = df2.values
Input = Model[:, :-1]
output = Model[:, -1]
output = np.reshape(output, (-1, 1))

Input_shape = Input.shape[1]

print('Input layer 0: ', Input[0, :10])
print('Output layer ~ 10: ', output[:10])

Input_transformer = MaxAbsScaler()
Output_transformer = StandardScaler()

Input = Input_transformer.fit_transform(Input)
Output = Output_transformer.fit_transform(output)

print('Input layer 0: ', Input[0, :10])
# Out:
# Index(['integrated_spike_B', 'integrated_spike_C', 'integrated_spike_D',
#        'integrated_spike_B_lower_noise', 'integrated_spike_C_lower_noise',
#        'integrated_spike_B_sg_B', 'integrated_spike_C_sg_D',
#        'integrated_spike_D_sg_F', 'Output'],
#       dtype='object')
# Input layer 0:  [ 25.016639    9.571132    0.99154     6.7658625   2.591525  200.785639
#   86.590132    0.99154  ]
# Output layer ~ 10:  [[0.10236723]
#  [0.13203094]
#  [0.18754876]
#  [0.19920984]
#  [0.22729473]
#  [0.26207539]
#  [0.2838152 ]
#  [0.30276893]
#  [0.31918277]
#  [0.33329432]]
# Input layer 0:  [0.0181653  0.00746002 0.01006404 0.0023528  0.00850592 0.02846079
#  0.02465728 0.01006098]

# %%
input_train, input_test, output_train, output_test = train_test_split(
    Input, output, test_size=0.1, random_state=42)
print('input_train.shape:\t', input_train.shape)
print('input_test.shape:\t', input_test.shape)
print('output_train.shape:\t', output_train.shape)
print('output_test.shape:\t', output_test.shape)

input_train = tf.convert_to_tensor(input_train)
input_test = tf.convert_to_tensor(input_test)
output_train = tf.convert_to_tensor(output_train)
output_test = tf.convert_to_tensor(output_test)
# Out:
# input_train.shape:	 (63, 8)
# input_test.shape:	 (7, 8)
# output_train.shape:	 (63, 1)
# output_test.shape:	 (7, 1)

# %%
model = Sequential()

model.add(Dense(128, activation='relu', input_dim=Input_shape))
#model.add(Dense(16, activation='relu'))
model.add(Dense(4, activation='relu'))
#model.add(Dense(2, activation='relu'))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1152
#
#  dense_1 (Dense)             (None, 4)                 516
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 1,673
# Trainable params: 1,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))


learning_rate = 0.0005
batch_size = 15
epochs = 500


# Adam RMSprop
model.compile(optimizer=tf.optimizers.Adam(
    learning_rate=learning_rate), loss=rmse)

start = time.time()
history = model.fit(input_train, output_train,
                    validation_data=(input_test, output_test), batch_size=batch_size, epochs=epochs, verbose=1)
end = time.time()

print('\n\n')
print('Training cost time:\t', end - start, 's')
print('\n\n')
# Out:
# Epoch 1/500
# 5/5 [==============================] - 2s 43ms/step - loss: 0.2818 - val_loss: 0.1895
# Epoch 2/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1835 - val_loss: 0.1286
# Epoch 3/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1087 - val_loss: 0.0868
# Epoch 4/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1159 - val_loss: 0.0721
# Epoch 5/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1192 - val_loss: 0.0651
# Epoch 6/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1068 - val_loss: 0.0623
# Epoch 7/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0863 - val_loss: 0.0651
# Epoch 8/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0721 - val_loss: 0.0714
# Epoch 9/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0665 - val_loss: 0.0572
# Epoch 10/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0569 - val_loss: 0.0430
# Epoch 11/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0494 - val_loss: 0.0369
# Epoch 12/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0423 - val_loss: 0.0338
# Epoch 13/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0359 - val_loss: 0.0319
# Epoch 14/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0326
# Epoch 15/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0294 - val_loss: 0.0338
# Epoch 16/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0296 - val_loss: 0.0337
# Epoch 17/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0279 - val_loss: 0.0337
# Epoch 18/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0277 - val_loss: 0.0331
# Epoch 19/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0295 - val_loss: 0.0347
# Epoch 20/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0262 - val_loss: 0.0326
# Epoch 21/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0258 - val_loss: 0.0327
# Epoch 22/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0255 - val_loss: 0.0326
# Epoch 23/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0250 - val_loss: 0.0321
# Epoch 24/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0286 - val_loss: 0.0336
# Epoch 25/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0264 - val_loss: 0.0320
# Epoch 26/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0249 - val_loss: 0.0311
# Epoch 27/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0260 - val_loss: 0.0305
# Epoch 28/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0241 - val_loss: 0.0305
# Epoch 29/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0242 - val_loss: 0.0304
# Epoch 30/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0238 - val_loss: 0.0301
# Epoch 31/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0248 - val_loss: 0.0297
# Epoch 32/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0241 - val_loss: 0.0297
# Epoch 33/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0234 - val_loss: 0.0292
# Epoch 34/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0236 - val_loss: 0.0290
# Epoch 35/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0249 - val_loss: 0.0287
# Epoch 36/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0219 - val_loss: 0.0292
# Epoch 37/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0252 - val_loss: 0.0281
# Epoch 38/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0220 - val_loss: 0.0283
# Epoch 39/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0239 - val_loss: 0.0273
# Epoch 40/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0223 - val_loss: 0.0268
# Epoch 41/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0227 - val_loss: 0.0266
# Epoch 42/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0225 - val_loss: 0.0269
# Epoch 43/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0223 - val_loss: 0.0266
# Epoch 44/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0238 - val_loss: 0.0267
# Epoch 45/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0231 - val_loss: 0.0260
# Epoch 46/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0224 - val_loss: 0.0257
# Epoch 47/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0232 - val_loss: 0.0279
# Epoch 48/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0242 - val_loss: 0.0253
# Epoch 49/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0219 - val_loss: 0.0248
# Epoch 50/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0214 - val_loss: 0.0246
# Epoch 51/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0215 - val_loss: 0.0246
# Epoch 52/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0223 - val_loss: 0.0238
# Epoch 53/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0210 - val_loss: 0.0238
# Epoch 54/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0209 - val_loss: 0.0239
# Epoch 55/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0220 - val_loss: 0.0249
# Epoch 56/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0216 - val_loss: 0.0236
# Epoch 57/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0198 - val_loss: 0.0236
# Epoch 58/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0213 - val_loss: 0.0228
# Epoch 59/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0219 - val_loss: 0.0225
# Epoch 60/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0200 - val_loss: 0.0227
# Epoch 61/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0209 - val_loss: 0.0224
# Epoch 62/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0196 - val_loss: 0.0223
# Epoch 63/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0199 - val_loss: 0.0231
# Epoch 64/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0199 - val_loss: 0.0221
# Epoch 65/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0202 - val_loss: 0.0230
# Epoch 66/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0233 - val_loss: 0.0302
# Epoch 67/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0244 - val_loss: 0.0221
# Epoch 68/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0202 - val_loss: 0.0209
# Epoch 69/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0199 - val_loss: 0.0206
# Epoch 70/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0195 - val_loss: 0.0201
# Epoch 71/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0190 - val_loss: 0.0201
# Epoch 72/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0209 - val_loss: 0.0202
# Epoch 73/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0183 - val_loss: 0.0213
# Epoch 74/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0195 - val_loss: 0.0216
# Epoch 75/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0189 - val_loss: 0.0197
# Epoch 76/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0182 - val_loss: 0.0197
# Epoch 77/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0184 - val_loss: 0.0198
# Epoch 78/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0209 - val_loss: 0.0207
# Epoch 79/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0245 - val_loss: 0.0267
# Epoch 80/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0199 - val_loss: 0.0208
# Epoch 81/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0222 - val_loss: 0.0192
# Epoch 82/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0185 - val_loss: 0.0193
# Epoch 83/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0185 - val_loss: 0.0186
# Epoch 84/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0176 - val_loss: 0.0193
# Epoch 85/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0177 - val_loss: 0.0184
# Epoch 86/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0177 - val_loss: 0.0185
# Epoch 87/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0185 - val_loss: 0.0181
# Epoch 88/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0196 - val_loss: 0.0179
# Epoch 89/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0183 - val_loss: 0.0189
# Epoch 90/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0185 - val_loss: 0.0182
# Epoch 91/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0172 - val_loss: 0.0216
# Epoch 92/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0197 - val_loss: 0.0208
# Epoch 93/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0187 - val_loss: 0.0170
# Epoch 94/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0167 - val_loss: 0.0171
# Epoch 95/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0182 - val_loss: 0.0187
# Epoch 96/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0169 - val_loss: 0.0164
# Epoch 97/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0161 - val_loss: 0.0181
# Epoch 98/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0163 - val_loss: 0.0166
# Epoch 99/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0179 - val_loss: 0.0184
# Epoch 100/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0169 - val_loss: 0.0178
# Epoch 101/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0160 - val_loss: 0.0164
# Epoch 102/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0157 - val_loss: 0.0166
# Epoch 103/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0161 - val_loss: 0.0177
# Epoch 104/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0163 - val_loss: 0.0157
# Epoch 105/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0159 - val_loss: 0.0163
# Epoch 106/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0165 - val_loss: 0.0199
# Epoch 107/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0184 - val_loss: 0.0178
# Epoch 108/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0171 - val_loss: 0.0141
# Epoch 109/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0171 - val_loss: 0.0154
# Epoch 110/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0157 - val_loss: 0.0148
# Epoch 111/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0153 - val_loss: 0.0173
# Epoch 112/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0161 - val_loss: 0.0156
# Epoch 113/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0157 - val_loss: 0.0151
# Epoch 114/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0152 - val_loss: 0.0156
# Epoch 115/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0151 - val_loss: 0.0157
# Epoch 116/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0159 - val_loss: 0.0182
# Epoch 117/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0187 - val_loss: 0.0177
# Epoch 118/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0192 - val_loss: 0.0156
# Epoch 119/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0176 - val_loss: 0.0192
# Epoch 120/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0169 - val_loss: 0.0167
# Epoch 121/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0158 - val_loss: 0.0162
# Epoch 122/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0149 - val_loss: 0.0158
# Epoch 123/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0161 - val_loss: 0.0172
# Epoch 124/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0156 - val_loss: 0.0141
# Epoch 125/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0169 - val_loss: 0.0146
# Epoch 126/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0145 - val_loss: 0.0148
# Epoch 127/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0144 - val_loss: 0.0136
# Epoch 128/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0146 - val_loss: 0.0135
# Epoch 129/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0144 - val_loss: 0.0155
# Epoch 130/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0171 - val_loss: 0.0149
# Epoch 131/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0151 - val_loss: 0.0137
# Epoch 132/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 0.0135
# Epoch 133/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0142 - val_loss: 0.0135
# Epoch 134/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0140 - val_loss: 0.0128
# Epoch 135/500
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0146 - val_loss: 0.0136
# Epoch 136/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0141 - val_loss: 0.0137
# Epoch 137/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0140 - val_loss: 0.0186
# Epoch 138/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0165 - val_loss: 0.0185
# Epoch 139/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 0.0137
# Epoch 140/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0143 - val_loss: 0.0143
# Epoch 141/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0153 - val_loss: 0.0135
# Epoch 142/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0158 - val_loss: 0.0150
# Epoch 143/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0178 - val_loss: 0.0152
# Epoch 144/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0155 - val_loss: 0.0143
# Epoch 145/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0141 - val_loss: 0.0139
# Epoch 146/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0139 - val_loss: 0.0141
# Epoch 147/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0134 - val_loss: 0.0147
# Epoch 148/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0144 - val_loss: 0.0160
# Epoch 149/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0159 - val_loss: 0.0152
# Epoch 150/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0162 - val_loss: 0.0131
# Epoch 151/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0171 - val_loss: 0.0189
# Epoch 152/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0178 - val_loss: 0.0162
# Epoch 153/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0166 - val_loss: 0.0146
# Epoch 154/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0154 - val_loss: 0.0120
# Epoch 155/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0153 - val_loss: 0.0124
# Epoch 156/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0127
# Epoch 157/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0142 - val_loss: 0.0137
# Epoch 158/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0129 - val_loss: 0.0141
# Epoch 159/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0133 - val_loss: 0.0119
# Epoch 160/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0136 - val_loss: 0.0119
# Epoch 161/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0137 - val_loss: 0.0199
# Epoch 162/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0206 - val_loss: 0.0175
# Epoch 163/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0190 - val_loss: 0.0143
# Epoch 164/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0150 - val_loss: 0.0128
# Epoch 165/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0148 - val_loss: 0.0123
# Epoch 166/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0133 - val_loss: 0.0166
# Epoch 167/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0157 - val_loss: 0.0125
# Epoch 168/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0146 - val_loss: 0.0113
# Epoch 169/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0129 - val_loss: 0.0118
# Epoch 170/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0145 - val_loss: 0.0137
# Epoch 171/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0174 - val_loss: 0.0184
# Epoch 172/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0158 - val_loss: 0.0132
# Epoch 173/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0185
# Epoch 174/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0150 - val_loss: 0.0121
# Epoch 175/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0175 - val_loss: 0.0119
# Epoch 176/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0154 - val_loss: 0.0155
# Epoch 177/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0158 - val_loss: 0.0125
# Epoch 178/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0179 - val_loss: 0.0197
# Epoch 179/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0147 - val_loss: 0.0127
# Epoch 180/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0133 - val_loss: 0.0135
# Epoch 181/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0133
# Epoch 182/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0190 - val_loss: 0.0156
# Epoch 183/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0150 - val_loss: 0.0176
# Epoch 184/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0129 - val_loss: 0.0129
# Epoch 185/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0135 - val_loss: 0.0135
# Epoch 186/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0154 - val_loss: 0.0119
# Epoch 187/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0145 - val_loss: 0.0112
# Epoch 188/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0139 - val_loss: 0.0161
# Epoch 189/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0136 - val_loss: 0.0108
# Epoch 190/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0113
# Epoch 191/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0126
# Epoch 192/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0113
# Epoch 193/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0107
# Epoch 194/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0111
# Epoch 195/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0104
# Epoch 196/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0105
# Epoch 197/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0169
# Epoch 198/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0171 - val_loss: 0.0128
# Epoch 199/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0090
# Epoch 200/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0129 - val_loss: 0.0118
# Epoch 201/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0135 - val_loss: 0.0103
# Epoch 202/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0188 - val_loss: 0.0100
# Epoch 203/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0137
# Epoch 204/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0111
# Epoch 205/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0095
# Epoch 206/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0111 - val_loss: 0.0102
# Epoch 207/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 208/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0112
# Epoch 209/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0132 - val_loss: 0.0115
# Epoch 210/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0120 - val_loss: 0.0089
# Epoch 211/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0119 - val_loss: 0.0101
# Epoch 212/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0095
# Epoch 213/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0111 - val_loss: 0.0122
# Epoch 214/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0121 - val_loss: 0.0102
# Epoch 215/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0110 - val_loss: 0.0126
# Epoch 216/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0113
# Epoch 217/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0151
# Epoch 218/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0151 - val_loss: 0.0090
# Epoch 219/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0136 - val_loss: 0.0091
# Epoch 220/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 0.0111
# Epoch 221/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0099
# Epoch 222/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0139 - val_loss: 0.0113
# Epoch 223/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0139 - val_loss: 0.0117
# Epoch 224/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0108 - val_loss: 0.0112
# Epoch 225/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0122 - val_loss: 0.0111
# Epoch 226/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0107 - val_loss: 0.0098
# Epoch 227/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0109 - val_loss: 0.0109
# Epoch 228/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0109 - val_loss: 0.0101
# Epoch 229/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0106 - val_loss: 0.0101
# Epoch 230/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0106 - val_loss: 0.0096
# Epoch 231/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0124
# Epoch 232/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0119
# Epoch 233/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0217 - val_loss: 0.0113
# Epoch 234/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0146 - val_loss: 0.0204
# Epoch 235/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0143 - val_loss: 0.0139
# Epoch 236/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0153 - val_loss: 0.0175
# Epoch 237/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0198 - val_loss: 0.0111
# Epoch 238/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0127 - val_loss: 0.0092
# Epoch 239/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0119
# Epoch 240/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0144 - val_loss: 0.0141
# Epoch 241/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0126 - val_loss: 0.0192
# Epoch 242/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0147 - val_loss: 0.0122
# Epoch 243/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 244/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0118 - val_loss: 0.0085
# Epoch 245/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0131 - val_loss: 0.0092
# Epoch 246/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0088
# Epoch 247/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0104 - val_loss: 0.0103
# Epoch 248/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0135
# Epoch 249/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0097
# Epoch 250/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0099 - val_loss: 0.0089
# Epoch 251/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0112 - val_loss: 0.0085
# Epoch 252/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0174 - val_loss: 0.0085
# Epoch 253/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0110
# Epoch 254/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0120 - val_loss: 0.0103
# Epoch 255/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0109
# Epoch 256/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0111 - val_loss: 0.0078
# Epoch 257/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0112 - val_loss: 0.0089
# Epoch 258/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0068
# Epoch 259/500
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0094
# Epoch 260/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0115 - val_loss: 0.0081
# Epoch 261/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0115 - val_loss: 0.0099
# Epoch 262/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0109 - val_loss: 0.0097
# Epoch 263/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0111 - val_loss: 0.0126
# Epoch 264/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 0.0095
# Epoch 265/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0106 - val_loss: 0.0118
# Epoch 266/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0103 - val_loss: 0.0089
# Epoch 267/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0110 - val_loss: 0.0108
# Epoch 268/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0112 - val_loss: 0.0103
# Epoch 269/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0130 - val_loss: 0.0149
# Epoch 270/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0129 - val_loss: 0.0081
# Epoch 271/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0108 - val_loss: 0.0080
# Epoch 272/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0097 - val_loss: 0.0084
# Epoch 273/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0096 - val_loss: 0.0088
# Epoch 274/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 275/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0107 - val_loss: 0.0079
# Epoch 276/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0111 - val_loss: 0.0103
# Epoch 277/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0128 - val_loss: 0.0069
# Epoch 278/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0097 - val_loss: 0.0079
# Epoch 279/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0120 - val_loss: 0.0089
# Epoch 280/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0079
# Epoch 281/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0114 - val_loss: 0.0123
# Epoch 282/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0111 - val_loss: 0.0088
# Epoch 283/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0138
# Epoch 284/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0141 - val_loss: 0.0074
# Epoch 285/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0108 - val_loss: 0.0077
# Epoch 286/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0100 - val_loss: 0.0092
# Epoch 287/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0096 - val_loss: 0.0095
# Epoch 288/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0099
# Epoch 289/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 290/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0105 - val_loss: 0.0129
# Epoch 291/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0113 - val_loss: 0.0088
# Epoch 292/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 293/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0091
# Epoch 294/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0093 - val_loss: 0.0087
# Epoch 295/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0101 - val_loss: 0.0081
# Epoch 296/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0087
# Epoch 297/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0131 - val_loss: 0.0106
# Epoch 298/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0097 - val_loss: 0.0081
# Epoch 299/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 300/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0119 - val_loss: 0.0069
# Epoch 301/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0113
# Epoch 302/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 0.0088
# Epoch 303/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0091
# Epoch 304/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 0.0090
# Epoch 305/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0139 - val_loss: 0.0089
# Epoch 306/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0110 - val_loss: 0.0076
# Epoch 307/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0145 - val_loss: 0.0072
# Epoch 308/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0113
# Epoch 309/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0102 - val_loss: 0.0071
# Epoch 310/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0125
# Epoch 311/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0143 - val_loss: 0.0066
# Epoch 312/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0141 - val_loss: 0.0065
# Epoch 313/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0079
# Epoch 314/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0062
# Epoch 315/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0113 - val_loss: 0.0077
# Epoch 316/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0140 - val_loss: 0.0083
# Epoch 317/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0110
# Epoch 318/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0100 - val_loss: 0.0080
# Epoch 319/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0093 - val_loss: 0.0072
# Epoch 320/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0091 - val_loss: 0.0083
# Epoch 321/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0096 - val_loss: 0.0117
# Epoch 322/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0087
# Epoch 323/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0092 - val_loss: 0.0128
# Epoch 324/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0125 - val_loss: 0.0078
# Epoch 325/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0097 - val_loss: 0.0075
# Epoch 326/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0080
# Epoch 327/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0106
# Epoch 328/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 329/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0098 - val_loss: 0.0101
# Epoch 330/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0092 - val_loss: 0.0084
# Epoch 331/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0093 - val_loss: 0.0086
# Epoch 332/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0108 - val_loss: 0.0080
# Epoch 333/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0136 - val_loss: 0.0080
# Epoch 334/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0111 - val_loss: 0.0082
# Epoch 335/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0097 - val_loss: 0.0096
# Epoch 336/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0104 - val_loss: 0.0099
# Epoch 337/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0096 - val_loss: 0.0094
# Epoch 338/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0089
# Epoch 339/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0099
# Epoch 340/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0093
# Epoch 341/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0085
# Epoch 342/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0099 - val_loss: 0.0081
# Epoch 343/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0098 - val_loss: 0.0096
# Epoch 344/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0100
# Epoch 345/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0089 - val_loss: 0.0079
# Epoch 346/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0097 - val_loss: 0.0091
# Epoch 347/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0071
# Epoch 348/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0077
# Epoch 349/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0090
# Epoch 350/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 0.0099
# Epoch 351/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0092 - val_loss: 0.0091
# Epoch 352/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0131 - val_loss: 0.0093
# Epoch 353/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0073
# Epoch 354/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0091 - val_loss: 0.0084
# Epoch 355/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0113 - val_loss: 0.0070
# Epoch 356/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0104 - val_loss: 0.0095
# Epoch 357/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0097 - val_loss: 0.0083
# Epoch 358/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0116 - val_loss: 0.0103
# Epoch 359/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0099 - val_loss: 0.0074
# Epoch 360/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0145 - val_loss: 0.0088
# Epoch 361/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0132 - val_loss: 0.0075
# Epoch 362/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0083
# Epoch 363/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 0.0100
# Epoch 364/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0089 - val_loss: 0.0081
# Epoch 365/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0096
# Epoch 366/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0095 - val_loss: 0.0078
# Epoch 367/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 368/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0086
# Epoch 369/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0103
# Epoch 370/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0096 - val_loss: 0.0090
# Epoch 371/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0087 - val_loss: 0.0086
# Epoch 372/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0093
# Epoch 373/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0113
# Epoch 374/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0088 - val_loss: 0.0107
# Epoch 375/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 376/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0093 - val_loss: 0.0093
# Epoch 377/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0092
# Epoch 378/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0089 - val_loss: 0.0105
# Epoch 379/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0089
# Epoch 380/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0084 - val_loss: 0.0099
# Epoch 381/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0105
# Epoch 382/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 0.0096
# Epoch 383/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0093 - val_loss: 0.0086
# Epoch 384/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0080
# Epoch 385/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 386/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 0.0089
# Epoch 387/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 388/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0099
# Epoch 389/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0096
# Epoch 390/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0107
# Epoch 391/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0098
# Epoch 392/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0097
# Epoch 393/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 0.0081
# Epoch 394/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0096
# Epoch 395/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0095
# Epoch 396/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0115
# Epoch 397/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0089 - val_loss: 0.0115
# Epoch 398/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0101 - val_loss: 0.0116
# Epoch 399/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0082 - val_loss: 0.0086
# Epoch 400/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 0.0131
# Epoch 401/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0108 - val_loss: 0.0080
# Epoch 402/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0084
# Epoch 403/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0093
# Epoch 404/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0088 - val_loss: 0.0097
# Epoch 405/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0089 - val_loss: 0.0096
# Epoch 406/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0080 - val_loss: 0.0087
# Epoch 407/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 408/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0087
# Epoch 409/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 410/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0086
# Epoch 411/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 0.0083
# Epoch 412/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 413/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0100
# Epoch 414/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 0.0101
# Epoch 415/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0096
# Epoch 416/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 417/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0084
# Epoch 418/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 419/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 420/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0084 - val_loss: 0.0088
# Epoch 421/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0080 - val_loss: 0.0108
# Epoch 422/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0088 - val_loss: 0.0110
# Epoch 423/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0089 - val_loss: 0.0096
# Epoch 424/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0082 - val_loss: 0.0090
# Epoch 425/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0092 - val_loss: 0.0079
# Epoch 426/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0089 - val_loss: 0.0083
# Epoch 427/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 0.0114
# Epoch 428/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0111 - val_loss: 0.0107
# Epoch 429/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0118
# Epoch 430/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0115 - val_loss: 0.0092
# Epoch 431/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0111 - val_loss: 0.0092
# Epoch 432/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0108 - val_loss: 0.0082
# Epoch 433/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0096
# Epoch 434/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0082 - val_loss: 0.0112
# Epoch 435/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0092 - val_loss: 0.0086
# Epoch 436/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0095 - val_loss: 0.0080
# Epoch 437/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0084 - val_loss: 0.0092
# Epoch 438/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0090
# Epoch 439/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0114 - val_loss: 0.0118
# Epoch 440/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0131 - val_loss: 0.0089
# Epoch 441/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0142 - val_loss: 0.0089
# Epoch 442/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0106 - val_loss: 0.0094
# Epoch 443/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 444/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0085
# Epoch 445/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0094
# Epoch 446/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 0.0097
# Epoch 447/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0077 - val_loss: 0.0090
# Epoch 448/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0077 - val_loss: 0.0084
# Epoch 449/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0119
# Epoch 450/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0092
# Epoch 451/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 452/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0092
# Epoch 453/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0095
# Epoch 454/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 455/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0090 - val_loss: 0.0110
# Epoch 456/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0122 - val_loss: 0.0095
# Epoch 457/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0141 - val_loss: 0.0098
# Epoch 458/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0152 - val_loss: 0.0082
# Epoch 459/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0089
# Epoch 460/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0120 - val_loss: 0.0093
# Epoch 461/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0106 - val_loss: 0.0089
# Epoch 462/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0104 - val_loss: 0.0113
# Epoch 463/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0090 - val_loss: 0.0091
# Epoch 464/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0089 - val_loss: 0.0117
# Epoch 465/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0089 - val_loss: 0.0079
# Epoch 466/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 467/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0085 - val_loss: 0.0071
# Epoch 468/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0082 - val_loss: 0.0079
# Epoch 469/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0076 - val_loss: 0.0098
# Epoch 470/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0081 - val_loss: 0.0087
# Epoch 471/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0076 - val_loss: 0.0089
# Epoch 472/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 473/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0081 - val_loss: 0.0077
# Epoch 474/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 475/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0082 - val_loss: 0.0088
# Epoch 476/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0077 - val_loss: 0.0093
# Epoch 477/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 478/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0099 - val_loss: 0.0085
# Epoch 479/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0080 - val_loss: 0.0088
# Epoch 480/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: 0.0127
# Epoch 481/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0102
# Epoch 482/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0147 - val_loss: 0.0129
# Epoch 483/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0089
# Epoch 484/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0111 - val_loss: 0.0084
# Epoch 485/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 486/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0095
# Epoch 487/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0101
# Epoch 488/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0082 - val_loss: 0.0107
# Epoch 489/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0098 - val_loss: 0.0111
# Epoch 490/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0093
# Epoch 491/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0075 - val_loss: 0.0093
# Epoch 492/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0076 - val_loss: 0.0084
# Epoch 493/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0092
# Epoch 494/500
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0096 - val_loss: 0.0099
# Epoch 495/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0104
# Epoch 496/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0078 - val_loss: 0.0124
# Epoch 497/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 498/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0077 - val_loss: 0.0124
# Epoch 499/500
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0109 - val_loss: 0.0095
# Epoch 500/500
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0115
#
#
#
# Training cost time:	 18.939640760421753 s

# %%
def numpy_rmse(actual, predict):
    return pow(np.mean(pow(actual - predict, 2)), 0.5)


test_predict = model.predict(input_test)
test_predict_actual = output_test.numpy()

test_predict = np.array(test_predict)

test_predict = Output_transformer.inverse_transform(test_predict)
test_predict_actual = Output_transformer.inverse_transform(test_predict_actual)

test_RMSE = numpy_rmse(test_predict_actual, test_predict)
print('Test: ')
print('Test RMSE:\t', test_RMSE)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# Test:
# Test RMSE:	 0.0016026020395881655

# %%
train_predict = model.predict(input_train)
train_predict_actual = output_train.numpy()

train_predict = Output_transformer.inverse_transform(train_predict)
train_predict_actual = Output_transformer.inverse_transform(
    train_predict_actual)

train_RMSE = numpy_rmse(train_predict_actual, train_predict)
print('\n\n\n')
print('Train: ')
print('Train RMSE:\t', train_RMSE)
# Out:
# 2/2 [==============================] - 0s 2ms/step
#
#
#
#
# Train:
# Train RMSE:	 0.0015866089697696617

# %%
total_predict = model.predict(Input)
total_predict_actual = output

total_predict = Output_transformer.inverse_transform(total_predict)
total_predict_actual = Output_transformer.inverse_transform(
    total_predict_actual)

total_RMSE = numpy_rmse(total_predict_actual, total_predict)
print('\n\n\n')
print('Total: ')
print('Total RMSE:\t', total_RMSE)
# Out:
# 3/3 [==============================] - 0s 997us/step
#
#
#
#
# Total:
# Total RMSE:	 0.0015882154353924567

# %%
fig, ax1 = plt.subplots(figsize=(100, 30))
plt.plot(total_predict_actual, linewidth=10.0)
plt.plot(total_predict, color='orange', linewidth=10.0)

# %%
path3 = 'test_data/'

sg_B = np.load(path3 + 'sg_B.npy')
sg_C = np.load(path3 + 'sg_C.npy')
sg_D = np.load(path3 + 'sg_D.npy')
sg_E = np.load(path3 + 'sg_E.npy')
sg_F = np.load(path3 + 'sg_F.npy')
sg_G = np.load(path3 + 'sg_G.npy')
sg_H = np.load(path3 + 'sg_H.npy')
sg_I = np.load(path3 + 'sg_I.npy')
BDF_distance = np.load(path3 + 'BDF_distance.npy')


spike_A = np.load(path3 + 'spike_A.npy')
spike_B = np.load(path3 + 'spike_B.npy')
spike_C = np.load(path3 + 'spike_C.npy')
spike_D = np.load(path3 + 'spike_D.npy')
spike_abs_B = np.load(path3 + 'spike_abs_B.npy')
spike_abs_C = np.load(path3 + 'spike_abs_C.npy')
spike_abs_D = np.load(path3 + 'spike_abs_D.npy')

spike_B_lower_noise = np.load(path3 + 'spike_B_lower_noise.npy')
spike_C_lower_noise = np.load(path3 + 'spike_C_lower_noise.npy')
spike_abs_B_lower_noise = np.load(path3 + 'spike_abs_B_lower_noise.npy')
spike_abs_C_lower_noise = np.load(path3 + 'spike_abs_C_lower_noise.npy')

BCD_distance = np.load(path3 + 'BCD_distance.npy')
BCD_abs_distance = np.load(path3 + 'BCD_abs_distance.npy')

# %%
print('preprocessing test data...')
spike_B_sum = spike_B.sum(axis=1)
spike_C_sum = spike_C.sum(axis=1)
spike_D_sum = spike_D.sum(axis=1)

spike_B_lower_noise_sum = spike_B_lower_noise.sum(axis=1)
spike_C_lower_noise_sum = spike_C_lower_noise.sum(axis=1)

spike_B_sg_B_sum = np.array([spike_B[i]-sg_B[i]
                            for i in range(len(spike_B))]).sum(axis=1)
spike_C_sg_D_sum = np.array([spike_C[i]-sg_D[i]
                             for i in range(len(spike_C))]).sum(axis=1)
spike_D_sg_F_sum = np.array([spike_D[i]-sg_F[i]
                             for i in range(len(spike_D))]).sum(axis=1)

df2 = pd.DataFrame()
integrated_spike_B = [sum(abs(spike_B_sum[:i]))
                      for i in range(1, len(spike_B_sum)+1)]
df2['integrated_spike_B'] = pd.Series(integrated_spike_B)

integrated_spike_C = [sum(abs(spike_C_sum[:i]))
                      for i in range(1, len(spike_C_sum)+1)]
df2['integrated_spike_C'] = pd.Series(integrated_spike_C)

integrated_spike_D = [sum(abs(spike_D_sum[:i]))
                      for i in range(1, len(spike_D_sum)+1)]
df2['integrated_spike_D'] = pd.Series(integrated_spike_D)

integrated_spike_B_lower_noise = [sum(abs(
    spike_B_lower_noise_sum[:i]))for i in range(1, len(spike_B_lower_noise_sum)+1)]
df2['integrated_spike_B_lower_noise'] = pd.Series(
    integrated_spike_B_lower_noise)

integrated_spike_C_lower_noise = [sum(abs(
    spike_C_lower_noise_sum[:i]))for i in range(1, len(spike_C_lower_noise_sum)+1)]
df2['integrated_spike_C_lower_noise'] = pd.Series(
    integrated_spike_C_lower_noise)

integrated_spike_B_sg_B_sum = [sum(abs(spike_B_sg_B_sum[:i]))
                      for i in range(1, len(spike_B_sg_B_sum)+1)]
df2['integrated_spike_B_sg_B_sum'] = pd.Series(integrated_spike_B_sg_B_sum)

integrated_spike_C_sg_D_sum = [sum(abs(spike_C_sg_D_sum[:i]))
                               for i in range(1, len(spike_C_sg_D_sum)+1)]
df2['integrated_spike_C_sg_D_sum'] = pd.Series(integrated_spike_C_sg_D_sum)

integrated_spike_D_sg_F_sum = [sum(abs(spike_D_sg_F_sum[:i]))
                               for i in range(1, len(spike_D_sg_F_sum)+1)]
df2['integrated_spike_D_sg_F_sum'] = pd.Series(integrated_spike_D_sg_F_sum)

columns = df2.columns
transformer = StandardScaler()
corr = pd.DataFrame(transformer.fit_transform(df2), columns=columns).corr()
print(corr.iloc[-1, :])
# Out:
# preprocessing test data...
# integrated_spike_B                0.996396
# integrated_spike_C                0.997764
# integrated_spike_D                1.000000
# integrated_spike_B_lower_noise    0.993249
# integrated_spike_C_lower_noise    0.992991
# integrated_spike_B_sg_B_sum       0.994751
# integrated_spike_C_sg_D_sum       0.997893
# integrated_spike_D_sg_F_sum       1.000000
# Name: integrated_spike_D_sg_F_sum, dtype: float64

# %%
print(df2.columns)
Model = df2.values
Input = Model

Input_shape = Input.shape[1]

print('Input layer 0: ', Input[0, :10])

Input = Input_transformer.transform(Input)

print('Input layer 0: ', Input[0, :10])
# Out:
# Index(['integrated_spike_B', 'integrated_spike_C', 'integrated_spike_D',
#        'integrated_spike_B_lower_noise', 'integrated_spike_C_lower_noise',
#        'integrated_spike_B_sg_B_sum', 'integrated_spike_C_sg_D_sum',
#        'integrated_spike_D_sg_F_sum'],
#       dtype='object')
# Input layer 0:  [ 25.016639    9.571132    0.99154     6.7658625   2.591525  200.785639
#   86.590132    0.99154  ]
# Input layer 0:  [0.0181653  0.00746002 0.01006404 0.0023528  0.00850592 0.02846079
#  0.02465728 0.01006098]

# %%
total_predict = model.predict(Input)
total_predict_actual = output

total_predict = Output_transformer.inverse_transform(total_predict)
total_predict_actual = Output_transformer.inverse_transform(
    total_predict_actual)

total_RMSE = numpy_rmse(total_predict_actual[0:25], total_predict)
print('\n\n\n')
print('Total: ')
print('Total RMSE:\t', total_RMSE)
# Out:
# 1/1 [==============================] - 0s 12ms/step
#
#
#
#
# Total:
# Total RMSE:	 0.0013790305431972696

# %%
fig, ax1 = plt.subplots(figsize=(100, 30))
plt.plot(total_predict_actual[0:25], linewidth=10.0)
plt.plot(total_predict, color='orange', linewidth=10.0)

# %%
total_predict = model.predict(Input)
# Out:
# 1/1 [==============================] - 0s 13ms/step

# %%
save_name = '111052_projectB_ans.csv'  

# load_name = '111052_projectB_ans.csv'
# df3 = pd.read_csv(load_name)
# df3.loc[:, 'MaxWear'] = total_predict
# df3.to_csv(save_name, index=False)

df3 = pd.DataFrame()
index = np.arange(1, 26)
df3['Index'] = pd.Series(index)
df3['MaxWear'] = total_predict
df3.to_csv(save_name, index=False)
print('Saved to ', save_name)
# Out:
# Saved to  111052_projectB_ans.csv
